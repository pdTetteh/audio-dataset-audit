# %% [markdown]
# # AudioDatasetAudit walkthrough
#
# This notebook demonstrates the intended workflow for the project.

# %%
from audiodatasetaudit.manifest import load_manifest

load_manifest('../examples/minimal_manifest.csv').head()
